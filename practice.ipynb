# %% [markdown]
# #pandas practice

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:\\data\\titanic.csv")
data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#       age  sibsp  parch    ticket      fare    cabin embarked boat body  \
# ...

# %%
data.tail(10)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1299       3         0                      Yasbeck, Mr. Antoni    male    27
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female    15
# 1301       3         0                     Youseff, Mr. Gerious    male  45.5
# 1302       3         0                        Yousif, Mr. Wazli    male     ?
# 1303       3         0                    Yousseff, Mr. Gerious    male     ?
# 1304       3         0                     Zabour, Miss. Hileni  female  14.5
# 1305       3         0                    Zabour, Miss. Thamine  female     ?
# 1306       3         0                Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                      Zakarian, Mr. Ortin    male    27
# 1308       3         0                       Zimmerman, Mr. Leo    male    29
#
#       sibsp  parch  ticket     fare cabin embarked boat body home.dest
# ...

# %%
data["pclass"].value_counts()
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
data["pclass"].value_counts(normalize=True)
# Out:
# pclass
# 3    0.541635
# 1    0.246753
# 2    0.211612
# Name: proportion, dtype: float64

# %%
data[data["pclass"] == 3] # with the help of this method we can see only the people whos num is 3
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male    42      0
# 601        3         0     Abbott, Master. Eugene Joseph    male    13      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male    16      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female    35      1
# 604        3         1       Abelseth, Miss. Karen Marie  female    16      0
# ...      ...       ...                               ...     ...   ...    ...
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0             Zabour, Miss. Thamine  female     ?      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male    27      0
# 1308       3         0                Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
data["pclass name"] = data["pclass"].map({1:"first",2:"second",3:"third"})

# %%
data.groupby("pclass")["survived"].mean() * 100
# Out:
# pclass
# 1    61.919505
# 2    42.960289
# 3    25.528914
# Name: survived, dtype: float64

# %%
data = data.rename(columns={"pclass" : "P-Class","name" : "Name"})
data
# Out:
#       P-Class  survived                                             Name  \
# 0           1         1                    Allen, Miss. Elisabeth Walton
# 1           1         1                   Allison, Master. Hudson Trevor
# 2           1         0                     Allison, Miss. Helen Loraine
# 3           1         0             Allison, Mr. Hudson Joshua Creighton
# 4           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...       ...       ...                                              ...
# 1304        3         0                             Zabour, Miss. Hileni
# 1305        3         0                            Zabour, Miss. Thamine
# 1306        3         0                        Zakarian, Mr. Mapriededer
# 1307        3         0                              Zakarian, Mr. Ortin
# 1308        3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data["P-Class"].value_counts()
# Out:
# P-Class
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
data.groupby("P-Class")["survived"].mean() *100
# Out:
# P-Class
# 1    61.919505
# 2    42.960289
# 3    25.528914
# Name: survived, dtype: float64

# %%
data = data.rename(columns={"survived" : "Survived"})
data
# Out:
#       P-Class  Survived                                             Name  \
# 0           1         1                    Allen, Miss. Elisabeth Walton
# 1           1         1                   Allison, Master. Hudson Trevor
# 2           1         0                     Allison, Miss. Helen Loraine
# 3           1         0             Allison, Mr. Hudson Joshua Creighton
# 4           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...       ...       ...                                              ...
# 1304        3         0                             Zabour, Miss. Hileni
# 1305        3         0                            Zabour, Miss. Thamine
# 1306        3         0                        Zakarian, Mr. Mapriededer
# 1307        3         0                              Zakarian, Mr. Ortin
# 1308        3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data.groupby("sex")["Survived"].mean() * 100
# Out:
# sex
# female    72.746781
# male      19.098458
# Name: Survived, dtype: float64

# %%
data["Survived"].value_counts()
# Out:
# Survived
# 0    809
# 1    500
# Name: count, dtype: int64

# %%
data["Survived"].value_counts(normalize=True) * 100
# Out:
# Survived
# 0    61.802903
# 1    38.197097
# Name: proportion, dtype: float64

# %%
data["type"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
data
# Out:
#       P-Class  Survived                                             Name  \
# 0           1         1                    Allen, Miss. Elisabeth Walton
# 1           1         1                   Allison, Master. Hudson Trevor
# 2           1         0                     Allison, Miss. Helen Loraine
# 3           1         0             Allison, Mr. Hudson Joshua Creighton
# 4           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...       ...       ...                                              ...
# 1304        3         0                             Zabour, Miss. Hileni
# 1305        3         0                            Zabour, Miss. Thamine
# 1306        3         0                        Zakarian, Mr. Mapriededer
# 1307        3         0                              Zakarian, Mr. Ortin
# 1308        3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data["f-name"] = data["sex"].map({"female" : data["Name"],"male" : "None"})
data
# Out:
#       P-Class  Survived                                             Name  \
# 0           1         1                    Allen, Miss. Elisabeth Walton
# 1           1         1                   Allison, Master. Hudson Trevor
# 2           1         0                     Allison, Miss. Helen Loraine
# 3           1         0             Allison, Mr. Hudson Joshua Creighton
# 4           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...       ...       ...                                              ...
# 1304        3         0                             Zabour, Miss. Hileni
# 1305        3         0                            Zabour, Miss. Thamine
# 1306        3         0                        Zakarian, Mr. Mapriededer
# 1307        3         0                              Zakarian, Mr. Ortin
# 1308        3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data["M-name"] = data["sex"].map({"male":data["Name"],"female" : "None"})
data
# Out:
#       P-Class  Survived                                             Name  \
# 0           1         1                    Allen, Miss. Elisabeth Walton
# 1           1         1                   Allison, Master. Hudson Trevor
# 2           1         0                     Allison, Miss. Helen Loraine
# 3           1         0             Allison, Mr. Hudson Joshua Creighton
# 4           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...       ...       ...                                              ...
# 1304        3         0                             Zabour, Miss. Hileni
# 1305        3         0                            Zabour, Miss. Thamine
# 1306        3         0                        Zakarian, Mr. Mapriededer
# 1307        3         0                              Zakarian, Mr. Ortin
# 1308        3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data["sex"].value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
data["sex"] = data["sex"].replace({"female":"F","male":"M"})
data
# Out:
#       P-Class  Survived                                             Name sex  \
# 0           1         1                    Allen, Miss. Elisabeth Walton   F
# 1           1         1                   Allison, Master. Hudson Trevor   M
# 2           1         0                     Allison, Miss. Helen Loraine   F
# 3           1         0             Allison, Mr. Hudson Joshua Creighton   M
# 4           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
# ...       ...       ...                                              ...  ..
# 1304        3         0                             Zabour, Miss. Hileni   F
# 1305        3         0                            Zabour, Miss. Thamine   F
# 1306        3         0                        Zakarian, Mr. Mapriededer   M
# 1307        3         0                              Zakarian, Mr. Ortin   M
# 1308        3         0                               Zimmerman, Mr. Leo   M
#
# ...

# %%
data
# Out:
#       P-Class  Survived                                             Name sex  \
# 0           1         1                    Allen, Miss. Elisabeth Walton   F
# 1           1         1                   Allison, Master. Hudson Trevor   M
# 2           1         0                     Allison, Miss. Helen Loraine   F
# 3           1         0             Allison, Mr. Hudson Joshua Creighton   M
# 4           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
# ...       ...       ...                                              ...  ..
# 1304        3         0                             Zabour, Miss. Hileni   F
# 1305        3         0                            Zabour, Miss. Thamine   F
# 1306        3         0                        Zakarian, Mr. Mapriededer   M
# 1307        3         0                              Zakarian, Mr. Ortin   M
# 1308        3         0                               Zimmerman, Mr. Leo   M
#
# ...

# %%
data["age"] = data["age"].replace("?",pd.NA)
data["age"] = data["age"].astype("float")

# %%
data
# Out:
#       P-Class  Survived                                             Name sex  \
# 0           1         1                    Allen, Miss. Elisabeth Walton   F
# 1           1         1                   Allison, Master. Hudson Trevor   M
# 2           1         0                     Allison, Miss. Helen Loraine   F
# 3           1         0             Allison, Mr. Hudson Joshua Creighton   M
# 4           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
# ...       ...       ...                                              ...  ..
# 1304        3         0                             Zabour, Miss. Hileni   F
# 1305        3         0                            Zabour, Miss. Thamine   F
# 1306        3         0                        Zakarian, Mr. Mapriededer   M
# 1307        3         0                              Zakarian, Mr. Ortin   M
# 1308        3         0                               Zimmerman, Mr. Leo   M
#
# ...

# %%
data.tail()
# Out:
#       P-Class  Survived                       Name     sex   age  sibsp  \
# 1304        3         0       Zabour, Miss. Hileni  female  14.5      1
# 1305        3         0      Zabour, Miss. Thamine  female   NaN      1
# 1306        3         0  Zakarian, Mr. Mapriededer    male  26.5      0
# 1307        3         0        Zakarian, Mr. Ortin    male  27.0      0
# 1308        3         0         Zimmerman, Mr. Leo    male  29.0      0
#
#       parch  ticket     fare cabin embarked boat body home.dest pclass name
# 1304      0    2665  14.4542     ?        C    ?  328         ?       third
# 1305      0    2665  14.4542     ?        C    ?    ?         ?       third
# 1306      0    2656    7.225     ?        C    ?  304         ?       third
# 1307      0    2670    7.225     ?        C    ?    ?         ?       third
# 1308      0  315082    7.875     ?        S    ?    ?         ?       third

# %%
data["age"].describe()
# Out:
# count    1046.000000
# mean       29.881135
# std        14.413500
# min         0.166700
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: age, dtype: float64

# %%
data["age"].fillna(data["age"].mean(),inplace=True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_6556\3250616897.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data["age"].fillna(data["age"].mean(),inplace=True)
# 0       29.000000
# 1        0.916700
# 2        2.000000
# 3       30.000000
# 4       25.000000
#           ...
# 1304    14.500000
# 1305    29.881135
# ...

# %%
data
# Out:
#       P-Class  Survived                                             Name  \
# 0           1         1                    Allen, Miss. Elisabeth Walton
# 1           1         1                   Allison, Master. Hudson Trevor
# 2           1         0                     Allison, Miss. Helen Loraine
# 3           1         0             Allison, Mr. Hudson Joshua Creighton
# 4           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...       ...       ...                                              ...
# 1304        3         0                             Zabour, Miss. Hileni
# 1305        3         0                            Zabour, Miss. Thamine
# 1306        3         0                        Zakarian, Mr. Mapriededer
# 1307        3         0                              Zakarian, Mr. Ortin
# 1308        3         0                               Zimmerman, Mr. Leo
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
data.tail(16)
# Out:
#       P-Class  Survived                                     Name     sex  \
# 1293        3         0        Williams, Mr. Howard Hugh 'Harry'    male
# 1294        3         0                     Williams, Mr. Leslie    male
# 1295        3         0                      Windelov, Mr. Einar    male
# 1296        3         0                         Wirz, Mr. Albert    male
# 1297        3         0                   Wiseman, Mr. Phillippe    male
# 1298        3         0                Wittevrongel, Mr. Camille    male
# 1299        3         0                      Yasbeck, Mr. Antoni    male
# 1300        3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female
# 1301        3         0                     Youseff, Mr. Gerious    male
# 1302        3         0                        Yousif, Mr. Wazli    male
# 1303        3         0                    Yousseff, Mr. Gerious    male
# 1304        3         0                     Zabour, Miss. Hileni  female
# ...

# %%
data["age"].value_counts()
# Out:
# age
# 29.881135    263
# 24.000000     47
# 22.000000     43
# 21.000000     41
# 30.000000     40
#             ...
# 60.500000      1
# 74.000000      1
# 0.416700       1
# 11.500000      1
# 26.500000      1
# Name: count, Length: 99, dtype: int64

# %%
data["age"].describe()
# Out:
# count    1309.000000
# mean       29.881135
# std        12.883199
# min         0.166700
# 25%        22.000000
# 50%        29.881135
# 75%        35.000000
# max        80.000000
# Name: age, dtype: float64

# %%
data["age"].min()
# Out:
# np.float64(0.1667)

# %%
data["age"].median()
# Out:
# np.float64(29.8811345124283)

# %%
bins = [0,12,18,40,80]
labels = ["kids","teenagers","adult","old main"]
data["age group"] = pd.cut(data["age"],bins=bins ,labels=labels)
data
# Out:
#       P-Class  Survived                                             Name  \
# 0           1         1                    Allen, Miss. Elisabeth Walton
# 1           1         1                   Allison, Master. Hudson Trevor
# 2           1         0                     Allison, Miss. Helen Loraine
# 3           1         0             Allison, Mr. Hudson Joshua Creighton
# 4           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...       ...       ...                                              ...
# 1304        3         0                             Zabour, Miss. Hileni
# 1305        3         0                            Zabour, Miss. Thamine
# 1306        3         0                        Zakarian, Mr. Mapriededer
# 1307        3         0                              Zakarian, Mr. Ortin
# 1308        3         0                               Zimmerman, Mr. Leo
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
data.tail(20)
# Out:
#       P-Class  Survived                                     Name     sex  \
# 1289        3         0                  Wiklund, Mr. Karl Johan    male
# 1290        3         1         Wilkes, Mrs. James (Ellen Needs)  female
# 1291        3         0         Willer, Mr. Aaron ('Abi Weller')    male
# 1292        3         0                       Willey, Mr. Edward    male
# 1293        3         0        Williams, Mr. Howard Hugh 'Harry'    male
# 1294        3         0                     Williams, Mr. Leslie    male
# 1295        3         0                      Windelov, Mr. Einar    male
# 1296        3         0                         Wirz, Mr. Albert    male
# 1297        3         0                   Wiseman, Mr. Phillippe    male
# 1298        3         0                Wittevrongel, Mr. Camille    male
# 1299        3         0                      Yasbeck, Mr. Antoni    male
# 1300        3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female
# ...

# %%
data["travel types"] = data["sibsp"].apply(lambda x : "alone" if x==0 else "with faimly" )
data
# Out:
#       P-Class  Survived                                             Name  \
# 0           1         1                    Allen, Miss. Elisabeth Walton
# 1           1         1                   Allison, Master. Hudson Trevor
# 2           1         0                     Allison, Miss. Helen Loraine
# 3           1         0             Allison, Mr. Hudson Joshua Creighton
# 4           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...       ...       ...                                              ...
# 1304        3         0                             Zabour, Miss. Hileni
# 1305        3         0                            Zabour, Miss. Thamine
# 1306        3         0                        Zakarian, Mr. Mapriededer
# 1307        3         0                              Zakarian, Mr. Ortin
# 1308        3         0                               Zimmerman, Mr. Leo
#
#          sex        age  sibsp  parch  ticket      fare    cabin embarked  \
# ...

# %%
data.tail(8)
# Out:
#       P-Class  Survived                       Name     sex        age  sibsp  \
# 1301        3         0       Youseff, Mr. Gerious    male  45.500000      0
# 1302        3         0          Yousif, Mr. Wazli    male  29.881135      0
# 1303        3         0      Yousseff, Mr. Gerious    male  29.881135      0
# 1304        3         0       Zabour, Miss. Hileni  female  14.500000      1
# 1305        3         0      Zabour, Miss. Thamine  female  29.881135      1
# 1306        3         0  Zakarian, Mr. Mapriededer    male  26.500000      0
# 1307        3         0        Zakarian, Mr. Ortin    male  27.000000      0
# 1308        3         0         Zimmerman, Mr. Leo    male  29.000000      0
#
#       parch  ticket     fare cabin embarked boat body home.dest pclass name  \
# 1301      0    2628    7.225     ?        C    ?  312         ?       third
# 1302      0    2647    7.225     ?        C    ?    ?         ?       third
# ...

# %%
data["sibsp"].mean()
# Out:
# np.float64(0.4988540870893812)

# %%
data["sibsp"].value_counts()
# Out:
# sibsp
# 0    891
# 1    319
# 2     42
# 4     22
# 3     20
# 8      9
# 5      6
# Name: count, dtype: int64

# %%
data[data["sibsp"] > 7]
# Out:
#       P-Class  Survived                               Name     sex        age  \
# 1170        3         0         Sage, Master. Thomas Henry    male  29.881135
# 1171        3         0        Sage, Master. William Henry    male  14.500000
# 1172        3         0                    Sage, Miss. Ada  female  29.881135
# 1173        3         0       Sage, Miss. Constance Gladys  female  29.881135
# 1174        3         0  Sage, Miss. Dorothy Edith 'Dolly'  female  29.881135
# 1175        3         0            Sage, Miss. Stella Anna  female  29.881135
# 1176        3         0           Sage, Mr. Douglas Bullen    male  29.881135
# 1177        3         0                Sage, Mr. Frederick    male  29.881135
# 1178        3         0           Sage, Mr. George John Jr    male  29.881135
#
#       sibsp  parch    ticket   fare cabin embarked boat body home.dest  \
# 1170      8      2  CA. 2343  69.55     ?        S    ?    ?         ?
# ...

# %%
data["parch"].value_counts()
# Out:
# parch
# 0    1002
# 1     170
# 2     113
# 3       8
# 4       6
# 5       6
# 6       2
# 9       2
# Name: count, dtype: int64

# %%
data["parch"].describe()
# Out:
# count    1309.000000
# mean        0.385027
# std         0.865560
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         9.000000
# Name: parch, dtype: float64

# %%
data["ticket"].value_counts()
# Out:
# ticket
# CA. 2343        11
# 1601             8
# CA 2144          8
# PC 17608         7
# S.O.C. 14879     7
#                 ..
# 2628             1
# 2647             1
# 2656             1
# 2670             1
# 315082           1
# Name: count, Length: 929, dtype: int64

# %%
data.fillna(data["fare"].mean(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[331], line 1
# ----> 1 data.fillna(data["fare"].mean(),inplace=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
# ...

# %%
data[data["fare"] == pd.NA]
# Out:
# Empty DataFrame
# Columns: [P-Class, Survived, Name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest, pclass name]
# Index: []

# %%
binz = [0,10,30,50,100]
labelz = ["sasta","normal price","mhenga","thora mhenga"]

data["group of prices"] = pd.cut(data["fare"],bins=binz ,labels=labelz)

data
# Out:
#       P-Class  Survived                                             Name  \
# 0           1         1                    Allen, Miss. Elisabeth Walton
# 1           1         1                   Allison, Master. Hudson Trevor
# 2           1         0                     Allison, Miss. Helen Loraine
# 3           1         0             Allison, Mr. Hudson Joshua Creighton
# 4           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...       ...       ...                                              ...
# 1304        3         0                             Zabour, Miss. Hileni
# 1305        3         0                            Zabour, Miss. Thamine
# 1306        3         0                        Zakarian, Mr. Mapriededer
# 1307        3         0                              Zakarian, Mr. Ortin
# 1308        3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
import pygame
# Out:
# pygame-ce 2.5.8 (SDL 2.32.10, Python 3.13.14)
