# %%
import numpy as np 
import pandas as pd

# %%
data = pd.DataFrame(np.arange(16).reshape(4,4),
        index=["skardu","shiger","khapolu","kharmang"],
        columns=["one","two","three","four"])

s1 = pd.Series(np.arange(5),index= ['a','b','c','d','e'])
s2 = pd.Series(np.arange(5),index=['a','b','c','g','h'])

data
# Out:
#           one  two  three  four
# skardu      0    1      2     3
# shiger      4    5      6     7
# khapolu     8    9     10    11
# kharmang   12   13     14    15

# %%
data.to_csv("data.csv") # to save any data in the form of csv

# %%
#for sorting
data.sort_values("two") # use for sort in the form of ascending
# Out:
#           one  two  three  four
# skardu      0    1      2     3
# shiger      4    5      6     7
# khapolu     8    9     10    11
# kharmang   12   13     14    15

# %%
data.sort_values("two",ascending=False) # use for descending order
# Out:
#           one  two  three  four
# kharmang   12   13     14    15
# khapolu     8    9     10    11
# shiger      4    5      6     7
# skardu      0    1      2     3

# %%
titanic.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 titanic.shape
#
# NameError: name 'titanic' is not defined

# %%
titanic["survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='survived'>

# %%
titanic[titanic["sex"] == "female"]["survived"].value_counts(normalize=True)
# Out:
# survived
# 1    0.727468
# 0    0.272532
# Name: proportion, dtype: float64

# %%
titanic["sex"].value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   str
#  3   sex        1309 non-null   str
#  4   age        1309 non-null   str
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   str
#  8   fare       1309 non-null   str
#  9   cabin      1309 non-null   str
#  10  embarked   1309 non-null   str
#  11  boat       1309 non-null   str
#  12  body       1309 non-null   str
#  13  home.dest  1309 non-null   str
# dtypes: int64(4), str(10)
# memory usage: 143.3 KB

# %%
titanic.describe()
# Out:
#             pclass     survived        sibsp        parch
# count  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971     0.498854     0.385027
# std       0.837836     0.486055     1.041658     0.865560
# min       1.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.000000     0.000000
# 50%       3.000000     0.000000     0.000000     0.000000
# 75%       3.000000     1.000000     1.000000     0.000000
# max       3.000000     1.000000     8.000000     9.000000

# %%
tita
