# %% [markdown]
# #titanic data set

# %%
import numpy as np 
import pandas as pd

# %%
titanic =pd.read_csv("C:\\data\\titanic.csv")
titanic.shape# to show first 10 rows of data
# Out:
# (1309, 14)

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   str
#  3   sex        1309 non-null   str
#  4   age        1309 non-null   str
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   str
#  8   fare       1309 non-null   str
#  9   cabin      1309 non-null   str
#  10  embarked   1309 non-null   str
#  11  boat       1309 non-null   str
#  12  body       1309 non-null   str
#  13  home.dest  1309 non-null   str
# dtypes: int64(4), str(10)
# memory usage: 143.3 KB

# %%
titanic.describe()
# Out:
#             pclass     survived        sibsp        parch
# count  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971     0.498854     0.385027
# std       0.837836     0.486055     1.041658     0.865560
# min       1.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.000000     0.000000
# 50%       3.000000     0.000000     0.000000     0.000000
# 75%       3.000000     1.000000     1.000000     0.000000
# max       3.000000     1.000000     8.000000     9.000000

# %%
titanic.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#       age  sibsp  parch    ticket      fare    cabin embarked boat body  \
# ...

# %%
titanic.tail(10)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1299       3         0                      Yasbeck, Mr. Antoni    male    27
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female    15
# 1301       3         0                     Youseff, Mr. Gerious    male  45.5
# 1302       3         0                        Yousif, Mr. Wazli    male     ?
# 1303       3         0                    Yousseff, Mr. Gerious    male     ?
# 1304       3         0                     Zabour, Miss. Hileni  female  14.5
# 1305       3         0                    Zabour, Miss. Thamine  female     ?
# 1306       3         0                Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                      Zakarian, Mr. Ortin    male    27
# 1308       3         0                       Zimmerman, Mr. Leo    male    29
#
#       sibsp  parch  ticket     fare cabin embarked boat body home.dest
# ...

# %%
titanic[titanic["ticket"] == titanic["ticket"].max()]
# Out:
#     pclass  survived                          name     sex age  sibsp  parch  \
# 81       1         0  Crosby, Capt. Edward Gifford    male  70      1      1
# 82       1         1       Crosby, Miss. Harriet R  female  36      0      2
#
#        ticket fare cabin embarked boat body      home.dest
# 81  WE/P 5735   71   B22        S    ?  269  Milwaukee, WI
# 82  WE/P 5735   71   B22        S    7    ?  Milwaukee, WI

# %%
titanic["ticket"].sort_index()
# Out:
# 0        24160
# 1       113781
# 2       113781
# 3       113781
# 4       113781
#          ...
# 1304      2665
# 1305      2665
# 1306      2656
# 1307      2670
# 1308    315082
# Name: ticket, Length: 1309, dtype: str

# %%
titanic =pd.read_csv("C:\\data\\titanic.csv")
titanic.shape# to show first 10 rows of data
# Out:
# (1309, 14)

# %%
titanic.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#       age  sibsp  parch    ticket      fare    cabin embarked boat body  \
# ...

# %%
d1 = pd.DataFrame({
    "name" :["ali",None,"ahmad","shahid","shakir"],
    "age" : [11,33,5,None,None],
    "marks" : [22,77,None,55,88]
})

d1.isna().sum() #use to find
# Out:
# name     1
# age      2
# marks    1
# dtype: int64

# %%
d2 = d1.copy()
d2
# Out:
#      name   age  marks
# 0     ali  11.0   22.0
# 1     NaN  33.0   77.0
# 2   ahmad   5.0    NaN
# 3  shahid   NaN   55.0
# 4  shakir   NaN   88.0

# %%
d2.fillna(0) #fill miss data with 0
# Out:
#      name   age  marks
# 0     ali  11.0   22.0
# 1       0  33.0   77.0
# 2   ahmad   5.0    0.0
# 3  shahid   0.0   55.0
# 4  shakir   0.0   88.0

# %%
mean_age = d2["age"].mean()
mean_marks = d2["marks"].mean()
d2.fillna({"name":"unknown","age":mean_age,"marks":mean_marks})
# Out:
#       name        age  marks
# 0      ali  11.000000   22.0
# 1  unknown  33.000000   77.0
# 2    ahmad   5.000000   60.5
# 3   shahid  16.333333   55.0
# 4   shakir  16.333333   88.0

# %%
d1.dropna(thresh=2)
# Out:
#      name   age  marks
# 0     ali  11.0   22.0
# 1     NaN  33.0   77.0
# 2   ahmad   5.0    NaN
# 3  shahid   NaN   55.0
# 4  shakir   NaN   88.0

# %%
titanic.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#       age  sibsp  parch    ticket      fare    cabin embarked boat body  \
# ...

# %%
#titanic[titanic]["sex"]==["female"]["fare"].sum()

# %%
titanic.groupby("sex")["fare"].sum()
# Out:
# sex
# female    211.3375151.55151.5577.958351.4792227.52569.37...
# male      151.55151.5526.55049.5042227.5253025.925247.52...
# Name: fare, dtype: str

# %%
titanic["sex"]= titanic["sex"].replace({"femail":"F","mail":"M"})

# %%
df4 = pd.DataFrame({
    "name" :["ali",None,"ahmad","shahid","shakir"],
    "age" : [11,33,5,None,None],
    "marks" : [22,77,None,55,88],
    "gender" : ["male","female","male","female","male"]
})
df4
# Out:
#      name   age  marks  gender
# 0     ali  11.0   22.0    male
# 1     NaN  33.0   77.0  female
# 2   ahmad   5.0    NaN    male
# 3  shahid   NaN   55.0  female
# 4  shakir   NaN   88.0    male

# %%
df4.head(3) #its use for top rows
# Out:
#     name   age  marks  gender
# 0    ali  11.0   22.0    male
# 1    NaN  33.0   77.0  female
# 2  ahmad   5.0    NaN    male

# %%
df4.tail(3) #its use for last rows
# Out:
#      name  age  marks  gender
# 2   ahmad  5.0    NaN    male
# 3  shahid  NaN   55.0  female
# 4  shakir  NaN   88.0    male

# %%
df4.shape
# Out:
# (5, 4)

# %%
print("number of rows:",df4.shape)
# Out:
# number of rows: (5, 4)

# %%
df4.describe() # it is use only to show numerical values
# Out:
#              age      marks
# count   3.000000   4.000000
# mean   16.333333  60.500000
# std    14.742230  29.103264
# min     5.000000  22.000000
# 25%     8.000000  46.750000
# 50%    11.000000  66.000000
# 75%    22.000000  79.750000
# max    33.000000  88.000000

# %%
df4.describe(include="all") # and this one is used for to shoe all the values
# Out:
#        name        age      marks gender
# count     4   3.000000   4.000000      5
# unique    4        NaN        NaN      2
# top     ali        NaN        NaN   male
# freq      1        NaN        NaN      3
# mean    NaN  16.333333  60.500000    NaN
# std     NaN  14.742230  29.103264    NaN
# min     NaN   5.000000  22.000000    NaN
# 25%     NaN   8.000000  46.750000    NaN
# 50%     NaN  11.000000  66.000000    NaN
# 75%     NaN  22.000000  79.750000    NaN
# max     NaN  33.000000  88.000000    NaN

# %%
df4
# Out:
#      name   age  marks  gender
# 0     ali  11.0   22.0    male
# 1     NaN  33.0   77.0  female
# 2   ahmad   5.0    NaN    male
# 3  shahid   NaN   55.0  female
# 4  shakir   NaN   88.0    male

# %%
df4["gender"].unique()
# Out:
# <StringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
df4["gender"].nunique() # it is use for to check the number of unique value in specific way
# Out:
# 2

# %%
df4["gender"].value_counts() #this method is use for to check the count value of unique valyes
# Out:
# gender
# male      3
# female    2
# Name: count, dtype: int64

# %%
df4["marks"]
# Out:
# 0    22.0
# 1    77.0
# 2     NaN
# 3    55.0
# 4    88.0
# Name: marks, dtype: float64

# %%
df4["marks"]>= 80
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: marks, dtype: bool

# %%
df4[df4["marks"]>= 80] # it will print only the rows which is more than 80
# Out:
#      name  age  marks gender
# 4  shakir  NaN   88.0   male

# %%
df4[(df4["marks"] >= 80) & (df4["marks"] <= 100)] # to care about brakects in this case
# Out:
#      name  age  marks gender
# 4  shakir  NaN   88.0   male

# %%
total_std_with_90 = len(df4[(df4["marks"] >= 80) & (df4["marks"] <= 100)])

# %%
print("total students which score is more than 90 and less than 100 :",total_std_with_90)
# Out:
# total students which score is more than 90 and less than 100 : 1

# %%
#2nd method to do the same thing
df4["marks"].between(80,100)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: marks, dtype: bool

# %%
sum(df4["marks"].between(80,100)) # it will return the std count valuse
#which marks is greater
#than 90 and less than 100
# Out:
# 1

# %%
df4
# Out:
#      name   age  marks  gender
# 0     ali  11.0   22.0    male
# 1     NaN  33.0   77.0  female
# 2   ahmad   5.0    NaN    male
# 3  shahid   NaN   55.0  female
# 4  shakir   NaN   88.0    male

# %%
df4["marks"].mean()
# Out:
# np.float64(60.5)

# %%
df4
# Out:
#      name   age  marks  gender
# 0     ali  11.0   22.0    male
# 1     NaN  33.0   77.0  female
# 2   ahmad   5.0    NaN    male
# 3  shahid   NaN   55.0  female
# 4  shakir   NaN   88.0    male

# %%
df4["marks"].fillna(df4["marks"].mean())
# Out:
# 0    22.0
# 1    77.0
# 2    60.5
# 3    55.0
# 4    88.0
# Name: marks, dtype: float64

# %%
df4
# Out:
#      name   age  marks  gender
# 0     ali  11.0   22.0    male
# 1     NaN  33.0   77.0  female
# 2   ahmad   5.0    NaN    male
# 3  shahid   NaN   55.0  female
# 4  shakir   NaN   88.0    male

# %%
df4["age"].fillna(df4["age"].mean())
# Out:
# 0    11.000000
# 1    33.000000
# 2     5.000000
# 3    16.333333
# 4    16.333333
# Name: age, dtype: float64

# %%
df4
# Out:
#      name   age  marks  gender
# 0     ali  11.0   22.0    male
# 1     NaN  33.0   77.0  female
# 2   ahmad   5.0    NaN    male
# 3  shahid   NaN   55.0  female
# 4  shakir   NaN   88.0    male

# %%
df4["name"]= df4["name"].astype(str)
df4
# Out:
#      name   age  marks  gender
# 0     ali  11.0   22.0    male
# 1     NaN  33.0   77.0  female
# 2   ahmad   5.0    NaN    male
# 3  shahid   NaN   55.0  female
# 4  shakir   NaN   88.0    male

# %%
df4["name"]
# Out:
# 0       ali
# 1       NaN
# 2     ahmad
# 3    shahid
# 4    shakir
# Name: name, dtype: str

# %%
df4["gender"].map({"male":"M","female":"F"})
# Out:
# 0    M
# 1    F
# 2    M
# 3    F
# 4    M
# Name: gender, dtype: str

# %%
df4
# Out:
#      name   age  marks  gender
# 0     ali  11.0   22.0    male
# 1     NaN  33.0   77.0  female
# 2   ahmad   5.0    NaN    male
# 3  shahid   NaN   55.0  female
# 4  shakir   NaN   88.0    male

# %%
df4["new gender"] = df4["gender"].map({"male":"M","female":"F"})
df4
# Out:
#      name   age  marks  gender new gender
# 0     ali  11.0   22.0    male          M
# 1     NaN  33.0   77.0  female          F
# 2   ahmad   5.0    NaN    male          M
# 3  shahid   NaN   55.0  female          F
# 4  shakir   NaN   88.0    male          M

# %%
df4["gender in number"] = df4["gender"].map({"male":1,"female":0})
df4
# Out:
#      name   age  marks  gender new gender  gender in number
# 0     ali  11.0   22.0    male          M                 1
# 1     NaN  33.0   77.0  female          F                 0
# 2   ahmad   5.0    NaN    male          M                 1
# 3  shahid   NaN   55.0  female          F                 0
# 4  shakir   NaN   88.0    male          M                 1

# %%
df4
# Out:
#      name   age  marks  gender new gender  gender in number
# 0     ali  11.0   22.0    male          M                 1
# 1     NaN  33.0   77.0  female          F                 0
# 2   ahmad   5.0    NaN    male          M                 1
# 3  shahid   NaN   55.0  female          F                 0
# 4  shakir   NaN   88.0    male          M                 1

# %%
df4= df4.drop("gender in number",axis=1)
df4
# Out:
#      name   age  marks  gender new gender
# 0     ali  11.0   22.0    male          M
# 1     NaN  33.0   77.0  female          F
# 2   ahmad   5.0    NaN    male          M
# 3  shahid   NaN   55.0  female          F
# 4  shakir   NaN   88.0    male          M

# %%
df4
# Out:
#      name   age  marks  gender new gender
# 0     ali  11.0   22.0    male          M
# 1     NaN  33.0   77.0  female          F
# 2   ahmad   5.0    NaN    male          M
# 3  shahid   NaN   55.0  female          F
# 4  shakir   NaN   88.0    male          M

# %%
df4 = df4.drop(["age","new gender"],axis=1)
df4
# Out:
#      name  marks  gender
# 0     ali   22.0    male
# 1     NaN   77.0  female
# 2   ahmad    NaN    male
# 3  shahid   55.0  female
# 4  shakir   88.0    male

# %%
df4
# Out:
#      name  marks  gender
# 0     ali   22.0    male
# 1     NaN   77.0  female
# 2   ahmad    NaN    male
# 3  shahid   55.0  female
# 4  shakir   88.0    male

# %%
df4.columns
# Out:
# Index(['name', 'marks', 'gender'], dtype='str')

# %%
df4.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df4
# Out:
#      name  marks  gender
# 0     ali   22.0    male
# 1     NaN   77.0  female
# 2   ahmad    NaN    male
# 3  shahid   55.0  female
# 4  shakir   88.0    male

# %%
df4.sort_values(by="marks") # sort in ascending order
# Out:
#      name  marks  gender
# 0     ali   22.0    male
# 3  shahid   55.0  female
# 1     NaN   77.0  female
# 4  shakir   88.0    male
# 2   ahmad    NaN    male

# %%
df4.sort_values(by="marks",ascending=False) # desending order
# Out:
#      name  marks  gender
# 4  shakir   88.0    male
# 1     NaN   77.0  female
# 3  shahid   55.0  female
# 0     ali   22.0    male
# 2   ahmad    NaN    male

# %%
df4.sort_values(by=["marks","gender","name"],ascending=False) # sort for multiple at once
df4
# Out:
#      name  marks  gender
# 0     ali   22.0    male
# 1     NaN   77.0  female
# 2   ahmad    NaN    male
# 3  shahid   55.0  female
# 4  shakir   88.0    male

# %%
df4["gender"]
# Out:
# 0      male
# 1    female
# 2      male
# 3    female
# 4      male
# Name: gender, dtype: str

# %%
df4["gender"] == "female"
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: gender, dtype: bool

# %%
df4[df4["gender"] == "female"] [["name","marks"]]
# Out:
#      name  marks
# 1     NaN   77.0
# 3  shahid   55.0

# %%
df4["gender"].isin(["female"])
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: gender, dtype: bool

# %%
df4[df4["gender"].isin(["female"])] [["name","marks"]]
# Out:
#      name  marks
# 1     NaN   77.0
# 3  shahid   55.0

# %%
titanic =pd.read_csv("C:\\data\\titanic.csv")

# %%
titanic.shape
# Out:
# (1309, 14)

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='str')

# %%
titanic.head(15)
# Out:
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 1        1         1                     Allison, Master. Hudson Trevor
# 2        1         0                       Allison, Miss. Helen Loraine
# 3        1         0               Allison, Mr. Hudson Joshua Creighton
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                                Anderson, Mr. Harry
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 7        1         0                             Andrews, Mr. Thomas Jr
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                            Artagaveytia, Mr. Ramon
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
titanic.value_counts(["sex"])
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
print(type(titanic["age"]))
# Out:
# <class 'pandas.Series'>

# %%
titanic["age"] = titanic["age"].resample
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex                                                age  sibsp  parch  \
# ...
